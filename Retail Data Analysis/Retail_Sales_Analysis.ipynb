# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b1e332f8-0448-48b3-936a-87f11567d12e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1e332f8-0448-48b3-936a-87f11567d12e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("business.retailsales.csv")

df.head()
# Out:
#       Product Type  Net Quantity  Gross Sales  Discounts  Returns  \
# 0  Art & Sculpture            34      14935.0    -594.00  -1609.0
# 1           Basket            13       3744.0    -316.80      0.0
# 2           Basket            12       3825.0    -201.60   -288.0
# 3           Basket            17       3035.0     -63.25      0.0
# 4  Art & Sculpture            47       2696.8     -44.16      0.0
#
#    Total Net Sales
# 0         12732.00
# 1          3427.20
# 2          3335.40
# 3          2971.75
# 4          2652.64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1775 entries, 0 to 1774
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Product Type     1767 non-null   object
#  1   Net Quantity     1775 non-null   int64
#  2   Gross Sales      1775 non-null   float64
#  3   Discounts        1775 non-null   float64
#  4   Returns          1775 non-null   float64
#  5   Total Net Sales  1775 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 83.3+ KB

# %%
df.describe()
# Out:
#        Net Quantity   Gross Sales    Discounts      Returns  Total Net Sales
# count   1775.000000   1775.000000  1775.000000  1775.000000      1775.000000
# mean       3.712676    199.671746    -6.317623    -5.385437       187.968687
# std        6.243078    464.880638    20.903517    46.654269       414.547039
# min       -1.000000      0.000000  -594.000000 -1609.000000      -106.250000
# 25%        1.000000     48.000000    -6.000000     0.000000        44.800000
# 50%        2.000000    100.000000     0.000000     0.000000        96.000000
# 75%        4.000000    185.500000     0.000000     0.000000       184.750000
# max       96.000000  14935.000000     0.000000     0.000000     12732.000000

# %%
df.isnull().sum()
# Out:
# Product Type       8
# Net Quantity       0
# Gross Sales        0
# Discounts          0
# Returns            0
# Total Net Sales    0
# dtype: int64

# %%
df = df.dropna()

df.isnull().sum()
# Out:
# Product Type       0
# Net Quantity       0
# Gross Sales        0
# Discounts          0
# Returns            0
# Total Net Sales    0
# dtype: int64

# %%
top_products.sort_values(ascending=False).head(10)
# Out:
# Product Type
# Basket             134791.39
# Art & Sculpture     84480.85
# Jewelry             29572.95
# Home Decor          25699.99
# Kitchen             15336.82
# Christmas           14460.81
# Soapstone            4629.09
# Accessories          3785.38
# Kids                 3721.34
# Recycled Art         3704.16
# Name: Total Net Sales, dtype: float64

# %%
top_returns = df.groupby('Product Type')['Returns'].sum()

top_returns.sort_values(ascending=False)
# Out:
# Product Type
# Accessories            0.00
# Fair Trade Gifts       0.00
# Recycled Art           0.00
# Easter                 0.00
# Gift Baskets           0.00
# Furniture              0.00
# One-of-a-Kind          0.00
# Skin Care              0.00
# Kids                   0.00
# Soapstone            -69.50
# Textiles             -97.00
# Music               -142.41
# Kitchen             -328.07
# Home Decor          -423.35
# Jewelry             -509.20
# Christmas           -670.00
# Art & Sculpture    -2879.93
# Basket             -4439.69
# Name: Returns, dtype: float64

# %%
monthly = pd.read_csv("business.retailsales2.csv")

monthly.head()
# Out:
#       Month  Year  Total Orders  Gross Sales  Discounts  Returns  Net Sales  \
# 0   January  2017            73       8861.5    -129.40  -448.45    8283.65
# 1  February  2017            56       6908.5    -104.70  -416.20    6387.60
# 2     March  2017            60       5778.5    -172.20 -1017.20    4589.10
# 3     April  2017            70       8814.0    -281.40     0.00    8532.60
# 4       May  2017            54       6677.0    -185.75  -253.80    6237.45
#
#    Shipping  Total Sales
# 0   1088.30      9371.95
# 1    892.45      7280.05
# 2    707.43      5296.53
# 3   1068.30      9600.90
# 4    866.46      7103.91

# %%
monthly[['Year','Total Sales']]
# Out:
#     Year  Total Sales
# 0   2017      9371.95
# 1   2017      7280.05
# 2   2017      5296.53
# 3   2017      9600.90
# 4   2017      7103.91
# 5   2017     10573.87
# 6   2017      6766.66
# 7   2017      8583.56
# 8   2017      7639.62
# 9   2017      6022.42
# 10  2017     14124.95
# 11  2017     11132.85
# 12  2018      9859.83
# 13  2018      7158.61
# 14  2018      8434.00
# 15  2018     10521.63
# 16  2018      7059.58
# 17  2018     13543.36
# 18  2018      9974.13
# 19  2018      8764.81
# 20  2018     11941.03
# 21  2018      7704.25
# 22  2018     13670.90
# 23  2018     14936.15
# 24  2019      7615.91
# 25  2019      7318.15
# 26  2019     13769.75
# 27  2019      8024.05
# 28  2019     11216.20
# 29  2019      8327.13
# 30  2019     10014.78
# 31  2019     10278.21
# 32  2019      9436.86
# 33  2019      8911.53
# 34  2019     27681.30
# 35  2019     33306.46

# %%
monthly.groupby('Year')['Total Sales'].sum()
# Out:
# Year
# 2017    103497.27
# 2018    123568.28
# 2019    155900.33
# Name: Total Sales, dtype: float64

# %%
monthly.groupby('Year')['Total Sales'].sum()
# Out:
# Year
# 2017    103497.27
# 2018    123568.28
# 2019    155900.33
# Name: Total Sales, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.heatmap(monthly.corr(numeric_only=True), annot=True)
plt.show()
